# %% [markdown]
# ## Web Scraping

# %% [markdown]
# ### Extracting Data
# ---
# #### Tools / Packages
#
#
# - Request package
# - HTTPX package (async)
# - playwright
# - Parsers
#     - beautiful soup
#     - selectolax
# - Framwroks
#     - scrapy

# %% [markdown]
# #### Skeleton Scrape Project

# %%
# import packages

def scrape(url):
    # get wap page
    pass

def parse(html):
    #parse html
    pass

def output(result):
    # output results
    pass

def main():
    pass

if __name__ =='__main__':
    pass
